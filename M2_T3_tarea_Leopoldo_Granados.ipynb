# %% [markdown]
# <a href="https://colab.research.google.com/github/grale13/cursoad/blob/main/M2_T3_tarea_Leopoldo_Granados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Distribución de Probabilidad

# %% [markdown]
# ##Importar bibliotecas de funciones importantes

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ##Importar el dataset - copiado al folder por facilidad

# %%
df = pd.read_csv('wine.data')
columns = ['class', 'Alcohol', 'Malic Acid', 'Ash', 'Alcalinity of ash', 'Magnesium', 'Total phenols', 'Flavanoids', 'Nonflavanoid phenols', 'Proanthocyanins', 'Color intensity', 'Hue', 'OD280/OD315 of diluted wines', 'Proline']
df.columns = columns
df.head()
# Out:
#    class  Alcohol  Malic Acid  ...   Hue  OD280/OD315 of diluted wines  Proline
# 0      1    13.20        1.78  ...  1.05                          3.40     1050
# 1      1    13.16        2.36  ...  1.03                          3.17     1185
# 2      1    14.37        1.95  ...  0.86                          3.45     1480
# 3      1    13.24        2.59  ...  1.04                          2.93      735
# 4      1    14.20        1.76  ...  1.05                          2.85     1450
#
# [5 rows x 14 columns]

# %%
import seaborn as sns
sns.set_theme()

# %%
class_1 = df[0:58]
class_2 = df[58:129]
class_3 = df[129:178]

# %% [markdown]
# ##Característica: Alcohol
# ##Distribución aproximada: Uniforme

# %%
sns.histplot(data = df, x = 'Alcohol', hue = "class", bins = 30, multiple="stack")

# %%
sns.distplot(df['Alcohol'], kde = True, color ='red', bins = 30)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ##Gráficas para entender mejor cómo funcionan los histogramas

# %%
sns.histplot(data = class_1, x = 'Alcohol', hue = "class", bins = 30)

# %%
sns.histplot(data = class_2, x = 'Alcohol', hue = "class", bins = 30)

# %%
sns.histplot(data = class_3, x = 'Alcohol', hue = "class", bins = 30)

# %% [markdown]
# ##Característica: Malic Acid
# ##Distribución aproximada: Exponencial

# %%
sns.histplot(data = df, x = 'Malic Acid', hue = "class", bins = 30, multiple="stack")

# %%
sns.distplot(df['Malic Acid'], kde = True, color ='red', bins = 30)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ##Característica: Ash
# ##Distribución aproximada: Normal

# %%
sns.histplot(data = df, x = 'Ash', hue = "class", bins = 30, multiple="stack")

# %%
sns.distplot(df['Ash'], kde = True, color ='red', bins = 30)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ##Característica: Alcalinity of ash
# ##Distribución aproximada: Normal

# %%
sns.histplot(data = df, x = 'Alcalinity of ash', hue = "class", bins = 30, multiple="stack")

# %%
sns.distplot(df['Alcalinity of ash'], kde = True, color ='red', bins = 30)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ##Característica: Magnesium
# ##Distribución aproximada: Exponencial

# %%
sns.histplot(data = df, x = 'Magnesium', hue = "class", bins = 30, multiple="stack")

# %%
sns.distplot(df['Magnesium'], kde = True, color ='red', bins = 30)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ##Característica: Total phenols
# ##Distribución aproximada: Uniforme

# %%
sns.histplot(data = df, x = 'Total phenols', hue = "class", bins = 30, multiple="stack")

# %%
sns.distplot(df['Total phenols'], kde = True, color ='red', bins = 30)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ##Característica: Flavanoids
# ##Distribución aproximada: Uniforme

# %%
sns.histplot(data = df, x = 'Flavanoids', hue = "class", bins = 30, multiple="stack")

# %%
sns.distplot(df['Flavanoids'], kde = True, color ='red', bins = 30)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ##Característica: Nonflavanoid phenols
# ##Distribución aproximada: Exponencial

# %%
sns.histplot(data = df, x = 'Nonflavanoid phenols', hue = "class", bins = 30, multiple="stack")

# %%
sns.distplot(df['Nonflavanoid phenols'], kde = True, color ='red', bins = 30)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ##Característica: Proanthocyanins
# ##Distribución aproximada: Normal

# %%
sns.histplot(data = df, x = 'Proanthocyanins', hue = "class", bins = 30, multiple="stack")

# %%
sns.distplot(df['Proanthocyanins'], kde = True, color ='red', bins = 30)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ##Característica: Color intensity
# ##Distribución aproximada: Exponencial

# %%
sns.histplot(data = df, x = 'Color intensity', hue = "class", bins = 30, multiple="stack")

# %%
sns.distplot(df['Color intensity'], kde = True, color ='red', bins = 30)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ##Característica: Hue
# ##Distribución aproximada: Normal

# %%
sns.histplot(data = df, x = 'Hue', hue = "class", bins = 30, multiple="stack")

# %%
sns.distplot(df['Hue'], kde = True, color ='red', bins = 30)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ##Característica: OD280/OD315 of diluted wines
# ##Distribución aproximada: Uniforme

# %%
sns.histplot(data = df, x = 'OD280/OD315 of diluted wines', hue = "class", bins = 30, multiple="stack")

# %%
sns.distplot(df['OD280/OD315 of diluted wines'], kde = True, color ='red', bins = 30)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ##Característica: Proline
# ##Distribución aproximada: Exponencial

# %%
sns.histplot(data = df, x = 'Proline', hue = "class", bins = 30, multiple="stack")

# %%
sns.distplot(df['Proline'], kde = True, color ='red', bins = 30)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
